# %% [markdown]
# # Automatic Reference Trace Generation
#
# This notebook demonstrates automatic generation of corrReference traces for out-of-focus detection.

# %%
import sys
sys.path.insert(0, '..')

from src.auto_reference import (
    parse_experiment_xml,
    compute_grid_traces,
    select_best_reference_roi,
    generate_reference_trace
)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Batch Processing (Multiple Folders)

# %%
from src.auto_reference import batch_generate_references
import pandas as pd

#Change to the location of the excel file with the list of experiments
df = pd.read_excel('../Ryr1-Myo15GCamp.xlsx')

#Change to the location of the data
drive = '/media/marcotti-lab' #Z:, D:
#######################


df['Folder'] = drive + df['Folder'].str[2:]

# List of experiment folders to process
folders = df['Folder'].values

if folders:
    results = batch_generate_references(folders, grid_size=[(4,3),(3,3)],smooth=False,skip_existing=True,plot=True,score_fraction=0.6, overlap=0.75,detect_oof=False)
    
    # Summary
    print("\n" + "="*60)
    print("Batch Processing Summary")
    print("="*60)
    for folder, res in results.items():
        if 'error' in res:
            print(f"FAILED: {folder} - {res['error']}")
        else:
            print(f"OK: {folder} - ROI {res['roi_index']}")
else:
    print("Add folder paths to the list above to run batch processing.")
# Out:
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/1
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/2
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/2_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/3
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/4
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/4_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/4_002
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/4_003
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/5
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/6
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/6_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/7
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/7_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/7_002
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/8
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/8_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/9
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/9_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10
#
# ============================================================
# Processing: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_001
# Generating ROI candidates for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_001...
#   - Generating ROIs for grid: (4, 3) with overlap 0.75
#   - Generating ROIs for grid: (3, 3) with overlap 0.75
# Total ROIs to analyze: 51
# Computing traces for 51 ROIs (single pass)...
# Selecting best reference ROI...
# Saved reference trace to /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_001/corrReference.csv
# Best ROI: index 22 (global), bounds (200, 280, 170, 512)
# Detected cutoff frame: 1597 (of 6141)
# ============================================================
# Processing: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_002
# Generating ROI candidates for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_002...
#   - Generating ROIs for grid: (4, 3) with overlap 0.75
#   - Generating ROIs for grid: (3, 3) with overlap 0.75
# Total ROIs to analyze: 51
# Computing traces for 51 ROIs (single pass)...
# Selecting best reference ROI...
# Saved reference trace to /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_002/corrReference.csv
# Best ROI: index 22 (global), bounds (200, 280, 170, 512)
# Detected cutoff frame: 3383 (of 13326)
# ============================================================
# Processing: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_003
# Generating ROI candidates for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_003...
#   - Generating ROIs for grid: (4, 3) with overlap 0.75
#   - Generating ROIs for grid: (3, 3) with overlap 0.75
# Total ROIs to analyze: 51
# Computing traces for 51 ROIs (single pass)...
# Selecting best reference ROI...
# Saved reference trace to /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_003/corrReference.csv
# Best ROI: index 16 (global), bounds (180, 260, 85, 426)
# Detected cutoff frame: 4819 (of 13497)
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/1
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/1_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/2
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/2_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/2_002
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/2_003
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/3
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/3_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/3_002
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/4
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/5
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6
#
# ============================================================
# Processing: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6_001
# Generating ROI candidates for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6_001...
#   - Generating ROIs for grid: (4, 3) with overlap 0.75
#   - Generating ROIs for grid: (3, 3) with overlap 0.75
# Total ROIs to analyze: 51
# Computing traces for 51 ROIs (single pass)...
# Selecting best reference ROI...
# Saved reference trace to /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6_001/corrReference.csv
# Best ROI: index 14 (global), bounds (100, 180, 85, 426)
# Detected cutoff frame: 5435 (of 5956)
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6_002
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/7
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/1
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/1_001
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/2
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3
#
# ============================================================
# Processing: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3_001
# Generating ROI candidates for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3_001...
#   - Generating ROIs for grid: (4, 3) with overlap 0.75
#   - Generating ROIs for grid: (3, 3) with overlap 0.75
# Total ROIs to analyze: 51
# Computing traces for 51 ROIs (single pass)...
# Selecting best reference ROI...
# Saved reference trace to /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3_001/corrReference.csv
# Best ROI: index 16 (global), bounds (198, 286, 85, 426)
# Detected cutoff frame: 2856 (of 7420)
# Skipping existing reference trace for /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3_002
#
# ============================================================
# Batch Processing Summary
# ============================================================
# OK: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_001 - ROI 22
# OK: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_002 - ROI 22
# OK: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260120-Ryr1Myo15GCaMP-P8/10_003 - ROI 16
# OK: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260121-Ryr1Myo15GCaMP/6_001 - ROI 14
# OK: /media/marcotti-lab/Users/Federico/Data/2026/Ryanodine Ryr1 mutant/20260122-Ryr1Myo15GCaMP/3_001 - ROI 16
